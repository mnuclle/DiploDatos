# %% [markdown]
# # Diplodatos Kaggle Competition

# %% [markdown]
# We present this peace of code to create the baseline for the competition, and as an example of how to deal with these kind of problems. The main goals are that you:
#
# 1. Learn
# 1. Try different models and see which one fits the best the given data
# 1. Get a higher score than the given one in the current baseline example
# 1. Try to get the highest score in the class :)

# %%
# Import the required packages
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#from ml.visualization import plot_confusion_matrix, plot_learning_curve
from sklearn.datasets import load_wine
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split



np.random.seed(1234) # Para mayor determinismo

# %%
# load the given labels
breed = pd.read_csv('../data/breed_labels.csv')
color = pd.read_csv('../data/color_labels.csv')
state = pd.read_csv('../data/state_labels.csv')

# %% [markdown]
# Now we take a look at the labels, just to understand what these are

# %%
breed.head()
# Out:
#    BreedID  Type         BreedName
# 0        1     1     Affenpinscher
# 1        2     1      Afghan Hound
# 2        3     1  Airedale Terrier
# 3        4     1            Akbash
# 4        5     1             Akita

# %%
color.head()
# Out:
#    ColorID ColorName
# 0        1     Black
# 1        2     Brown
# 2        3    Golden
# 3        4    Yellow
# 4        5     Cream

# %%
state
# Out:
#     StateID        StateName
# 0     41336            Johor
# 1     41325            Kedah
# 2     41367         Kelantan
# 3     41401     Kuala Lumpur
# 4     41415           Labuan
# 5     41324           Melaka
# 6     41332  Negeri Sembilan
# 7     41335           Pahang
# 8     41330            Perak
# 9     41380           Perlis
# 10    41327     Pulau Pinang
# 11    41345            Sabah
# 12    41342          Sarawak
# 13    41326         Selangor
# 14    41361       Terengganu

# %% [markdown]
# And now we are ready to deal with the *original* dataset...

# %%
original_df = pd.read_csv('../data/train.csv')

# %%
original_df.columns
# Out:
# Index(['Type', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'Description',
#        'AdoptionSpeed', 'PID'],
#       dtype='object')

# %% [markdown]
# Create a function to transform the datasets. This is done by means of a function so that the transformations are the same for the training and testing datasets... We replace the encodings just to make it easy to "visualize" the data

# %%
def transform_data(train_data_fname, test_data_fname):
    def transform_columns(df):
        df = df.drop(["Description"], axis=1)
        df.Type = df.Type.replace({1: 'Dog', 2: 'Cat'})
        df.Gender = df.Gender.replace({1:'Male', 2:'Female', 3:'Mixed'})
        df.MaturitySize = df.MaturitySize.replace({1:'S', 2:'M', 3:'L', 4:'XL', 0:'N/A'})
        df.FurLength = df.FurLength.replace({1:'S', 2:'M', 3:'L', 0:'N/A'})
        df.Vaccinated = df.Vaccinated.replace({1:'T', 2:'N', 3:'N/A'})
        df.Dewormed = df.Dewormed.replace({1:'T', 2:'F', 3:'N/A'})
        df.Sterilized = df.Sterilized.replace({1:'T', 2:'F', 3:'N/A'})
        df.Health = df.Health.replace({1:'Healthy', 2: 'MinorInjury', 3:'SeriousInjury', 0: 'N/A'})
        df.Color1 = df.Color1.replace(dict(list(zip(color.ColorID, color.ColorName)) + [(0, "N/A")]))
        df.Color2 = df.Color2.replace(dict(list(zip(color.ColorID, color.ColorName)) + [(0, "N/A")]))
        df.Color3 = df.Color3.replace(dict(list(zip(color.ColorID, color.ColorName)) + [(0, "N/A")]))
        df.Breed1 = df.Breed1.replace(dict(list(zip(breed.BreedID, breed.BreedName)) + [(0, "N/A")]))
        df.Breed2 = df.Breed2.replace(dict(list(zip(breed.BreedID, breed.BreedName)) + [(0, "N/A")]))
        return df
    
    df_train = pd.read_csv(train_data_fname)
    df_train = transform_columns(df_train)
    df_test = pd.read_csv(test_data_fname)
    df_test = transform_columns(df_test)
    
    df = pd.concat([df_train, df_test], sort=True)

    # set dummy variables for everything
    # except from Age, Quantity, Fee
    df = pd.get_dummies(df)
    # get train and test back
    n = len(df_train)
    df_train = df.iloc[:n]
    df_test = df.iloc[n:]
    
    y = df_train['AdoptionSpeed']
    X = df_train.drop('AdoptionSpeed', axis=1)
    yy = None
    XX = df_test.drop('AdoptionSpeed', axis=1)

    return X, y, XX, yy

# %% [markdown]
# Load the data...

# %%
X, y, XX, yy = transform_data("../data/train.csv", "../data/test.csv")

# %% [markdown]
# Create the model and evaluate it

# %% [markdown]
# ###SGDClassifier

# %%
plt.figure(figsize=(14, 4), dpi= 80, facecolor='w', edgecolor='k')

from sklearn.tree import SGDClassifier as SGDClassifier

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=42)

results = pd.DataFrame(columns=('clf', 'best_acc'))
results = []


#HIPERPARAMETROS
for idx, loss in enumerate(('hinge', 'log', 'perceptron'), start=1):
    exploring_params = {
        'learning_rate': ['constant','optimal','invscaling','adaptive'],
        'eta0': [0.1, 0.01, 0.001, 0.001],  # Tasa de entrenamiento
        'alpha': [0.1, 0.01, 0.001,0.00001]  # Tasa de regularización
    }
    m = SGDClassifier(loss=loss, tol=1e-3)
    model = GridSearchCV(m, exploring_params, cv=5, scoring='accuracy')
   
    #entrenar los datos de entrenamiento eliminando los PID para entrenar
    model.fit(X_train.drop(["PID"], axis=1), y_train)

    
    print("# Exploración de hiperparámetros para función de coste \"%s\"" % loss, end="\n\n")
    
    print("Mejor conjunto de parámetros:")
    print(model.best_params_, end="\n\n")
    
    print("Mejor Estimador:")
    print(model.best_estimator_, end="\n\n")
    
    print("Mejor Accuracy:")
    print(model.best_score_, end="\n\n")

    results.append({'clf': model.best_estimator_, 'best_acc': model.best_score_}) #sacar el ignore index para results como lista
    results = pd.DataFrame(results)
    
    print('The best classifier so far is: ')
    print(results.loc[results['best_acc'].idxmax()]['clf'])
# Out:
# # Exploración de hiperparámetros para función de coste "hinge"
#
# Mejor conjunto de parámetros:
# {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
#
# Puntajes de la grilla:
#
# Exactitud: 0.187 (+/-0.007) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.236 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.075 (+/-0.010) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.249 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.213 (+/-0.009) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.230 (+/-0.008) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.186 (+/-0.007) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.222 (+/-0.000) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.163 (+/-0.013) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.236 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.213 (+/-0.009) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.258 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.214 (+/-0.009) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.238 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.199 (+/-0.008) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.202 (+/-0.008) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.264 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.227 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.216 (+/-0.005) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.187 (+/-0.007) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.276 (+/-0.000) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.150 (+/-0.011) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.254 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.162 (+/-0.013) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.253 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.251 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.263 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.258 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.212 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.214 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.267 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.212 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.201 (+/-0.008) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.227 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.252 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.212 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.175 (+/-0.006) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.257 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.294 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.225 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.226 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.226 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.259 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.238 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.237 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.199 (+/-0.008) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.270 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.247 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.261 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.210 (+/-0.009) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.246 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.264 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.212 (+/-0.009) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.237 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.216 (+/-0.010) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.262 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.275 (+/-0.000) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.238 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.269 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.246 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.252 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.221 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.198 (+/-0.007) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'adaptive'}
#
# # Exploración de hiperparámetros para función de coste "log"
#
# Mejor conjunto de parámetros:
# {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
#
# Puntajes de la grilla:
#
# Exactitud: 0.224 (+/-0.010) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.235 (+/-0.007) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.201 (+/-0.008) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.194 (+/-0.005) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.115 (+/-0.012) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.249 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.114 (+/-0.012) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.218 (+/-0.000) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.127 (+/-0.015) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.251 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.200 (+/-0.008) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.252 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.212 (+/-0.009) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.233 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.150 (+/-0.011) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.237 (+/-0.006) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.252 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.264 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.251 (+/-0.000) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.214 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.248 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.211 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.225 (+/-0.004) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.214 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.279 (+/-0.000) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.227 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.262 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.200 (+/-0.008) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.176 (+/-0.015) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.260 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.276 (+/-0.002) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.213 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.254 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.225 (+/-0.010) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.236 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.189 (+/-0.007) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.262 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.274 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.276 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.186 (+/-0.007) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.214 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.152 (+/-0.011) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.278 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.236 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.251 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.210 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.210 (+/-0.007) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.175 (+/-0.006) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.249 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.200 (+/-0.008) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.249 (+/-0.003) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.253 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.211 (+/-0.009) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.286 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.236 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.213 (+/-0.009) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.150 (+/-0.010) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.273 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.242 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.263 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.186 (+/-0.007) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.239 (+/-0.004) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# # Exploración de hiperparámetros para función de coste "perceptron"
#
# Mejor conjunto de parámetros:
# {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
#
# Puntajes de la grilla:
#
# Exactitud: 0.189 (+/-0.007) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.229 (+/-0.000) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.249 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.191 (+/-0.006) para los parámetros {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.062 (+/-0.005) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.239 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.248 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.235 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.242 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.287 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.213 (+/-0.009) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.188 (+/-0.007) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.238 (+/-0.001) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.176 (+/-0.007) para los parámetros {'alpha': 0.1, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.151 (+/-0.011) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.236 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.212 (+/-0.000) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.212 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.262 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.249 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.193 (+/-0.011) para los parámetros {'alpha': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.264 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.211 (+/-0.009) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.176 (+/-0.015) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.177 (+/-0.006) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.248 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.248 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.259 (+/-0.001) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.250 (+/-0.000) para los parámetros {'alpha': 0.01, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.126 (+/-0.015) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.225 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.213 (+/-0.009) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.271 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.235 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.248 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.225 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.273 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.270 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.239 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.274 (+/-0.000) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.274 (+/-0.001) para los parámetros {'alpha': 0.001, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.224 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'constant'}
# Exactitud: 0.225 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# Exactitud: 0.200 (+/-0.008) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# Exactitud: 0.219 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# Exactitud: 0.262 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'constant'}
# Exactitud: 0.217 (+/-0.009) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# Exactitud: 0.192 (+/-0.007) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# Exactitud: 0.285 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# Exactitud: 0.239 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.200 (+/-0.008) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.191 (+/-0.007) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.240 (+/-0.004) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'adaptive'}
# Exactitud: 0.210 (+/-0.000) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'constant'}
# Exactitud: 0.250 (+/-0.001) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'optimal'}
# Exactitud: 0.214 (+/-0.009) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'invscaling'}
# Exactitud: 0.205 (+/-0.008) para los parámetros {'alpha': 1e-05, 'eta0': 0.001, 'learning_rate': 'adaptive'}

# %%
## prediccion

print("Reporte de clasificación para el mejor clasificador (sobre conjunto de evaluación):", end="\n\n")
yy = results.model.iloc[0].predict(XX.drop(["PID"], axis=1))
yy = yy.astype(np.int)
#y_true, y_pred = y_test, model.predict(XX.drop(["PID"], axis=1))
#print(classification_report(y_true, y_pred), end="\n\n")
#plt.subplot(1, 3, idx)
#plot_confusion_matrix(confusion_matrix(y_true, y_pred),
#classes=wine_data.target_names, title="Matriz de confusión para %s" % loss)

# %%
submission = pd.DataFrame(list(zip(XX.PID, yy)), columns=["PID", "AdoptionSpeed"])
submission.to_csv("../data/submission.csv", header=True, index=False)

# %%
results

# %% [markdown]
# **And finally**, we predict the unknown label for the testing set

# %%
X.shape, XX.shape

# %%
yy = results.clf.iloc[0].predict(XX.drop(["PID"], axis=1))
yy = yy.astype(np.int)

# %% [markdown]
# The last thing we do is generating a file that should be *submitted* on kaggle

# %%
submission = pd.DataFrame(list(zip(XX.PID, yy)), columns=["PID", "AdoptionSpeed"])

# %%
submission.to_csv("../data/submission.csv", header=True, index=False)
