# %% [markdown]
# <center><h1>Time series analysis</h1></center>
# <center><h2>Tutorial 2: Forecasting</h2></center>
# <br>
#
# This tutorial we study the practical application of basic forecasting methods in Python.
#
# <a class="buttom" href=">#Data:-Australian-CPI-Inflation">Data: Australian CPI inflation</a> <br>
# <a class="buttom" href="#Exploratory-data-analysis">Exploratory data analysis</a> <br>
# <a class="buttom" href="#Random-Walk">Random Walk</a> <br>
# <a class="buttom" href="#Simple-Exponential-Smoothing">Simple Exponential Smoothing</a> <br>
# <a class="buttom" href="#Model-diagnostics">Model diagnostics</a> <br>
# <a class="buttom" href="#Model-validation">Model validation</a> <br>
# <a class="buttom" href="#Forecast">Forecast</a> <br>
#
# Based in the work of Marcel Scharth http://www.marcelscharth.com/
#
# This notebook relies on the following imports and settings.

# %%
# Packages
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
# Plot settings
sns.set_context('notebook') 
sns.set_style('ticks')
red='#D62728'
blue='#1F77B4'
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# ### Dataset Telefonía Móvil

# %%
#Opción para meter manualmente el rango de los períodos 
periods_tel = pd.period_range('2013Q1','2019Q1', freq='Q')
periods_tel
# Out:
# PeriodIndex(['2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2',
#              '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4',
#              '2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#              '2017Q3', '2017Q4', '2018Q1', '2018Q2', '2018Q3', '2018Q4',
#              '2019Q1'],
#             dtype='period[Q-DEC]', freq='Q-DEC')

# %%
data_tel = pd.read_csv('Telefonia_movil.csv')
data_tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
# Año                                   25 non-null int64
# Trimestre                             25 non-null int64
# Minutos pospago salientes (miles)     25 non-null object
# Minutos prepago salientes (miles)     25 non-null int64
# Total de minutos salientes (miles)    25 non-null int64
# Periodo                               25 non-null object
# dtypes: int64(4), object(2)
# memory usage: 1.2+ KB

# %%
data_tel['Parsed_period'] = data_tel['Año'].astype(str)+'Q'+data_tel['Trimestre'].astype(str)

list_period = pd.PeriodIndex(data=list(data_tel.Parsed_period),freq='Q')
data_tel['Parsed_period'] = list_period

data_tel = data_tel.drop(columns=['Año','Trimestre','Periodo'])
data_tel = data_tel.set_index('Parsed_period')

data_tel.head()
# Out:
#               Minutos pospago salientes (miles)  \
# Parsed_period
# 2013Q1                                8.785.943
# 2013Q2                                9.512.689
# 2013Q3                               10.315.484
# 2013Q4                                9.809.515
# 2014Q1                               10.128.751
#
#                Minutos prepago salientes (miles)  \
# Parsed_period
# 2013Q1                                   6582117
# 2013Q2                                   7108640
# 2013Q3                                   7335154
# 2013Q4                                   6250549
# 2014Q1                                   5799223
#
#                Total de minutos salientes (miles)
# Parsed_period
# 2013Q1                                   15368060
# 2013Q2                                   16621329
# 2013Q3                                   17650638
# 2013Q4                                   16060064
# 2014Q1                                   15927974

# %%
data_tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 25 entries, 2013Q1 to 2019Q1
# Freq: Q-DEC
# Data columns (total 3 columns):
# Minutos pospago salientes (miles)     25 non-null object
# Minutos prepago salientes (miles)     25 non-null int64
# Total de minutos salientes (miles)    25 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 800.0+ bytes

# %% [markdown]
# Limpiamos el set de datos transformando en int todas las series:

# %%
data_tel['Minutos pospago salientes (miles)'] = data_tel['Minutos pospago salientes (miles)'].str.replace('.','').astype(int)
data_tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 25 entries, 2013Q1 to 2019Q1
# Freq: Q-DEC
# Data columns (total 3 columns):
# Minutos pospago salientes (miles)     25 non-null int32
# Minutos prepago salientes (miles)     25 non-null int64
# Total de minutos salientes (miles)    25 non-null int64
# dtypes: int32(1), int64(2)
# memory usage: 700.0 bytes

# %% [markdown]
# Definimos nuestras series a analizar:

# %%
y_pospago = data_tel['Minutos pospago salientes (miles)']
y_prepago = data_tel['Minutos prepago salientes (miles)']

# %%
fig, ax= plt.subplots();#figsize=(9,6))
y_pospago.plot(color='r')
y_prepago.plot(color='b')
ax.set_xlabel('')
ax.set_ylabel('Series de Minutos')
ax.set_title('Telefonía Móvil')
ax.set_xticks([], minor=True) # I prefer to remove the minor ticks for a cleaner plot

sns.despine()
plt.legend(loc='center right', bbox_to_anchor=(1.23, 0.5), ncol=1)
plt.show()

# %% [markdown]
# ## Random Walk

# %% [markdown]
# Aplicamos el algoritmo visto en clase:

# %% [markdown]
# - Serie Pospago

# %%
serie_inicio_pos = y_pospago.index[-1]+1
h = 6
test=pd.period_range(start=serie_inicio_pos, periods=h, freq='Q')
pred_pos=pd.Series(np.repeat(y_pospago.iloc[-1], h), index=test) # the forecast repeats the last observed values h times
pred_pos
# Out:
# 2019Q2    13937271
# 2019Q3    13937271
# 2019Q4    13937271
# 2020Q1    13937271
# 2020Q2    13937271
# 2020Q3    13937271
# Freq: Q-DEC, dtype: int32

# %% [markdown]
# ## Data: Australian CPI inflation
#
# Our data is the quarterly change in the Consumer Price Index (CPI) calculated by the Australian Bureau of Statistics. The original dataset is in the [ABS website](http://www.abs.gov.au/AUSSTATS/abs@.nsf/DetailsPage/6401.0Jun%202016?OpenDocument), where you can also find the [explanatory notes](http://www.abs.gov.au/AUSSTATS/abs@.nsf/Lookup/6401.0Explanatory%20Notes1Jun%202016?OpenDocument). We use the index for all expenditure groups, which according to the ABS documentation already contains seasonal adjustments for components that are subject to calendar effects.
#
# We start by loading the data and converting the index to quarterly periods (note that we have to specify this frequency when converting the index). We focus on the data since 1980, which has a total of 146 observations.

# %%
oridata=pd.read_csv('inflation.csv', index_col='Date', parse_dates=True, dayfirst=True)
oridata.head()
# Out:
#             Inflation
# Date
# 1948-12-01        2.7
# 1949-03-01        2.6
# 1949-06-01        2.6
# 1949-09-01        2.5
# 1949-12-01        0.0

# %%
data=pd.read_csv('inflation.csv', index_col='Date', parse_dates=True, dayfirst=True)
data.index=data.index.to_period(freq='Q') # converting the index to quarterly period instead of dates
data=data['1980':] # filtering the use data from Jan/1980 onwards
data.tail()
# Out:
#         Inflation
# Date
# 2017Q3        0.6
# 2017Q4        0.6
# 2018Q1        0.4
# 2018Q2        0.4
# 2018Q3        0.4

# %% [markdown]
# For univariate time series modelling, it is better to work with a pandas series rather than dataframe.

# %%
y=data['Inflation']
y
# Out:
# Date
# 1980Q1    2.0
# 1980Q2    3.1
# 1980Q3    1.5
# 1980Q4    2.3
# 1981Q1    2.2
# 1981Q2    2.2
# 1981Q3    2.1
# 1981Q4    4.1
# 1982Q1    2.0
# 1982Q2    2.3
# 1982Q3    3.5
# 1982Q4    3.1
# 1983Q1    2.1
# 1983Q2    2.0
# 1983Q3    1.7
# 1983Q4    2.5
# 1984Q1   -0.5
# 1984Q2    0.3
# 1984Q3    1.4
# 1984Q4    1.4
# 1985Q1    1.3
# 1985Q2    2.4
# 1985Q3    2.3
# 1985Q4    2.0
# 1986Q1    2.2
# 1986Q2    1.7
# 1986Q3    2.6
# 1986Q4    2.8
# 1987Q1    2.0
# 1987Q2    1.5
#          ...
# 2011Q2    0.9
# 2011Q3    0.6
# 2011Q4    0.0
# 2012Q1    0.1
# 2012Q2    0.5
# 2012Q3    1.4
# 2012Q4    0.2
# 2013Q1    0.4
# 2013Q2    0.4
# 2013Q3    1.2
# 2013Q4    0.8
# 2014Q1    0.6
# 2014Q2    0.5
# 2014Q3    0.5
# 2014Q4    0.2
# 2015Q1    0.2
# 2015Q2    0.7
# 2015Q3    0.5
# 2015Q4    0.4
# 2016Q1   -0.2
# 2016Q2    0.4
# 2016Q3    0.7
# 2016Q4    0.5
# 2017Q1    0.5
# 2017Q2    0.2
# 2017Q3    0.6
# 2017Q4    0.6
# 2018Q1    0.4
# 2018Q2    0.4
# 2018Q3    0.4
# Freq: Q-DEC, Name: Inflation, Length: 155, dtype: float64

# %% [markdown]
# ## Exploratory data analysis
#
# The first step in our analysis is a time series plot. We can see that both the level and volatility of inflation is much lower in recent times than it was in the 80s. There is a noticeable outlier in the third quarter of 2000 due to introduction of the GST in Australia.

# %%
fig, ax= plt.subplots();#figsize=(9,6))
y.plot(color=red)
ax.set_xlabel('')
ax.set_ylabel('Inflation')
ax.set_title('Australian Quarterly CPI Inflation')
ax.set_xticks([], minor=True) # I prefer to remove the minor ticks for a cleaner plot
sns.despine()
plt.show()

# %%
y.describe().round(2)
# Out:
# count    155.00
# mean       0.99
# std        0.87
# min       -0.50
# 25%        0.40
# 50%        0.70
# 75%        1.50
# max        4.10
# Name: Inflation, dtype: float64

# %% [markdown]
# ## Random walk
#
# In this section we use the random walk method to illustrate the process that we will follow to generate forecasts in the tutorials.
#
# 1. Specify the forecast horizon.
#
# 2. Create a range of dates or periods starting from the time index following the last observation in the data.
#
# 3. Generate the forecasts and store them in a series indexed by step 2.
#
# Below, we generate point forecasts for one to four quarters after the end of the series.

# %%
serie_inicio = y.index[-1]+1
h = 6
test=pd.period_range(start=serie_inicio, periods=h, freq='Q')
pred=pd.Series(np.repeat(y.iloc[-1], h), index=test) # the forecast repeats the last observed values h times
pred
# Out:
# 2018Q4    0.4
# 2019Q1    0.4
# 2019Q2    0.4
# 2019Q3    0.4
# 2019Q4    0.4
# 2020Q1    0.4
# Freq: Q-DEC, dtype: float64

# %% [markdown]
# To compute interval forecasts, we first estimate the standard deviation of the errors.

# %%
resid=y-y.shift(1) # the shift lags the series by one period
sigma = resid.std()
round(sigma,3)
# Out:
# 0.785

# %%
resid.plot.hist(bins=30)

# %% [markdown]
# Using the formulas from the lecture, the interval forecasts are as below.

# %%
#Cálculo del intervalo de confianza para todas las predicciones
intv = pd.concat([pred-stats.norm.ppf(0.975)*sigma*np.sqrt(np.arange(1,h+1)),
                   pred+stats.norm.ppf(0.975)*sigma*np.sqrt(np.arange(1,h+1))], axis=1)
intv.round(3)
# Out:
#             0      1
# 2018Q4 -1.138  1.938
# 2019Q1 -1.775  2.575
# 2019Q2 -2.264  3.064
# 2019Q3 -2.676  3.476
# 2019Q4 -3.039  3.839
# 2020Q1 -3.367  4.167

# %%
from plotting import fanchart

point_pred = (intv[0]+intv[1])/2

fig, ax = fanchart(y['1980':],point_pred,intv,intv,intv)

plt.show()

# %% [markdown]
# ## Simple exponential smoothing
#
# The exponential smoothing functions are available since version 0.9 of statsmodels in the **tsa.
# holtwinters** module. Take a look in the official [docs](https://www.statsmodels.org/stable/tsa.html#exponential-smoothing). Also, they are improving them, so follow the news for the next release.

# %%
model_ses = sm.tsa.SimpleExpSmoothing(y).fit()
fitted_ses = model_ses.fittedvalues
model_ses.summary()

# %% [markdown]
# Also AIC and BIC looks off so we are continue our analysis with MSE.

# %%
mse_ses = sm.tools.eval_measures.mse(y,fitted_ses)
print(' In-sample fit:')
print(' MSE               {0:.3f}'.format(mse_ses))
# Out:
#  In-sample fit:
#  MSE               0.410

# %% [markdown]
# You can calculate AIC and BIC as follows

# %%
N = len(y)
loglik_ses=-(N/2)*(1+np.log(2*np.pi))-(N/2)*np.log(mse_ses)
aic_ses=-2*loglik_ses+2*3
bic_ses=-2*loglik_ses+np.log(N)*3
print(' Log-likelihood    %.3f' % (loglik_ses))
print(' AIC               {0:.3f}'.format(aic_ses))
print(' BIC               {0:.3f}'.format(bic_ses))
# Out:
#  Log-likelihood    -150.786
#  AIC               307.571
#  BIC               316.701

# %% [markdown]
# Now, let's see how the smoothed data fits the original data

# %%
fig, ax= plt.subplots();#figsize=(9,6))
y.plot(color=red, label='Inflation')
fitted_ses.plot(color='black', label='Simple exponential smoothing fit', alpha=0.8)
ax.set_xlabel('')
ax.set_ylabel('Inflation')
ax.set_title('Australian Quarterly CPI Inflation')
ax.set_xticks([], minor=True) 
plt.legend(loc='best')
sns.despine()
plt.show()

# %% [markdown]
# ## Model diagnostics
#
# We now conduct residual diagnostics for the exponential smoothing. Recall from the lectures that the key diagnostics for univariate time series are:
#
# 1. Residual plot.
# 2. Residual autocorrelation function (ACF) plot.
# 3. Residual distribution plots.
#
# We compute the residuals as follows.

# %%
resid=y-fitted_ses # model_ses.resid isn't a panda.Series, so no index, no plot

# %% [markdown]
# The following cells compute the diagnostics. We find that the residuals are uncorrelated, have non-constant variance (due to higher volatitility in the 80s), and are non-Gaussian.

# %%
fig, ax= plt.subplots();#figsize=(9,6))
resid.plot(color=blue)
ax.set_xlabel('')
ax.set_xticks([], minor=True) 
ax.set_title('Residual plot')
sns.despine()
plt.show()

# %% [markdown]
# Next is the residual ACF plot aka correlogram

# %%
fig, ax = plt.subplots();#figsize=(9,6))
sm.graphics.tsa.plot_acf(resid, lags=40, ax=ax)
sns.despine()
plt.show()

# %% [markdown]
# Plotting histogram (in blue) and kernel density estimation (in black) for the residuals

# %%
def hist(series):
    fig, ax= plt.subplots();#figsize=(9,6))
    sns.distplot(series, ax=ax, hist_kws={'alpha': 0.8, 'edgecolor':'black', 'color': blue},  
                 kde_kws={'color': 'black', 'alpha': 0.7})
    sns.despine()
    return fig, ax

hist(resid)
plt.show()
# Out:
# C:\Users\Gabriel H\.conda\envs\diplodatos\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Model validation
#
# We implement a real time forecasting exercise to compare the random walk and simple exponential smoothing methods.

# %%
porcen_data = (y.index.get_loc('2004Q1')-1)/len(y)
porcen_data
# Out:
# 0.6129032258064516

# %%
# Real time forecasting - use it as a template - expanding window

validation=y['2004Q1':].index # the validation period is Q1 2004 onwards
start = y.index.get_loc('2004Q1') # numerical index corresponding to Q1 2004

pred1 = []
pred2 = []
actual= []
for i in range(start, len(y)):
    
    actual.append(y.iloc[i]) # actual value
    
    #Como el random walk es el valor anterior no necesitamos modelo. 
    pred1.append(y.iloc[i-1]) # random walk forecast
    
    model = sm.tsa.SimpleExpSmoothing(y.iloc[:i]).fit() 
    pred2.append(model.forecast(1)[0]) # SES forecast

columns=['RW', 'SES', 'Actual']
results_sm = np.vstack([pred1,pred2,actual]).T
results_sm = pd.DataFrame(results_sm, columns=columns, index=validation)
results_sm.tail()
# Out:
#          RW       SES  Actual
# Date
# 2017Q3  0.2  0.386171     0.6
# 2017Q4  0.6  0.446716     0.6
# 2018Q1  0.6  0.490131     0.4
# 2018Q2  0.4  0.464593     0.4
# 2018Q3  0.4  0.446321     0.4

# %% [markdown]
# We find that simple exponential smoothing generates more accurate forecasts.

# %%
#Armamos tabla base para alamcenar resultados de las métricas
table = pd.DataFrame(0.0, index=results_sm.columns[:-1], columns=['RMSE','SE'])
table
# Out:
#      RMSE   SE
# RW    0.0  0.0
# SES   0.0  0.0

# %%
from scipy import stats

for i in range(2):
    table.iloc[i,0] = sm.tools.eval_measures.rmse(results_sm.iloc[:,i], results_sm.iloc[:,-1])
    table.iloc[i,1] = (results_sm.iloc[:,i] - results_sm.iloc[:,-1]).sem()
table.round(3)
# Out:
#       RMSE     SE
# RW   0.518  0.068
# SES  0.446  0.059

# %% [markdown]
# ## Forecast
#
# We show how to do expanding and rolling point forecast.

# %%
h=12
w=h*10
data = y
model = sm.tsa.SimpleExpSmoothing
pred_index = y.index[-1] + np.array(range(1,h+1))
pred_rolling = pd.Series(0,index=pred_index)
pred_expanding = pd.Series(0,index=pred_index)
orig_exp = None
orig_roll = None
for i in range(0,h):
    #Current_exp, son los datos para entrenar el expanding
    current_exp = pd.concat([data, pred_expanding.head(i)])
    expanding = model(current_exp).fit()
    pred_expanding.update(expanding.forecast(1))
    
    #Current_roll tmb son los usados para entrenar pero nos quedamos con el tail(w) por que la ventana se va moviendo.
    current_roll = pd.concat([data, pred_rolling.head(i)])
    rolling = model(current_roll.tail(w)).fit()
    pred_rolling.update(rolling.forecast(1))
    
    if i==0:
        orig_fit = expanding.fittedvalues
        orig_roll = rolling.fittedvalues
ax = data[-w:].plot(color='red');#figsize=(9,6))
pd.concat([orig_fit[-w:],pred_expanding]).plot(ax=ax,color='blue');
pd.concat([orig_roll[-w:],pred_rolling]).plot(ax=ax,color='green');

# %%
pred_rolling['2019']
# Out:
# 2019Q1    0.434514
# 2019Q2    0.433489
# 2019Q3    0.434233
# 2019Q4    0.436523
# Freq: Q-DEC, dtype: float64

# %% [markdown]
# In this case, **statsmodels** doesn't provide interval forecast

# %% [markdown]
# 1. Análisis y definicipon del modelo aplicado a toda la serie. No se hacen predicciones en esta etapa, simplemente ver si el modelo ajusta a la serie origen
# 2. Division en train y validation para evaluación de métricas
# 3. Entrenamos con los datos de la serie original de la parte train. Finalmente vamos agrandando el set de training con el método expanding window (Hacemos N predicciones de 1 valor, es decir h=1)
# 4. Análisis de las métricas calculadas entre la comparación de esta predicción vs la serie original que habíamos separado validation
# 5. Predicciones: nuestra y serie base desaparece, no la consideramos ya que esto es lo que buscamos predecir. Tenemos la opción de predecir dejando una ventana base fija y corriendola tomando también mis predicciones pasadas. O Tambien agrandar la ventana a medida que voy armando nuevas predicciones. Este criterio dependerá de si se considera que los datos del pasado influyen en las predicciones.
